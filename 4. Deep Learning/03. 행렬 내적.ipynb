# %%
import numpy as np

# %%
A = np.array([[1, 2],
              [3, 4],
              [5, 6]])

B = np.array([[10, 11],
              [12, 13],
              [14, 15]])

# %%
A.shape
# Out:
# (3, 2)

# %%
B.shape
# Out:
# (3, 2)

# %%
A @ B.T # (3, 2) @ (2, 3) -> (3, 3)
# Out:
# array([[ 32,  38,  44],
#        [ 74,  88, 102],
#        [116, 138, 160]])

# %%
A.T @ B # (2, 3) @ (3, 2) -> (2, 2)
# Out:
# array([[116, 125],
#        [152, 164]])
